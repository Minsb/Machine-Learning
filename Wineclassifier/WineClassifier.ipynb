# %%
from tensorflow import keras

keras.__version__
# Out:
# '2.2.4-tf'

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
# Data set source https://archive.ics.uci.edu/ml/datasets/Wine+Quality)
# * white wine / red wine CSV file
# * input variables (X)
#     * fixed acidity
#     * volatile acidity
#     * citric acid
#     * residual sugar
#     * chlorides
#     * free sulfur dioxide
#     * total sulfur dioxide
#     * density
#     * pH
#     * sulphates
#     * alcohol
# * class label (Y)
#    * quality (0~10, 0: Very poor, 10: Very excellent)
# * no Missing Value

# %%
import pandas as pd
pd.__version__
pd.options.display.max_rows=15

# %%
import numpy as np
np.__version__
# Out:
# '1.19.2'

# %%
white_wine = pd.read_csv("winequality-white.csv")
red_wine = pd.read_csv("winequality-red.csv")

# %%
display(white_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
display(red_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                      11                    34  0.99780  3.51       0.56
# 1                      25                    67  0.99680  3.20       0.68
# 2                      15                    54  0.99700  3.26       0.65
# 3                      17                    60  0.99800  3.16       0.58
# 4                      11                    34  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                   32                    44  0.99490  3.45       0.58
# 1595                   39                    51  0.99512  3.52       0.76
# 1596                   29                    40  0.99574  3.42       0.75
# 1597                   32                    44  0.99547  3.57       0.71
# 1598                   18                    42  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#####################################################
def generate_data(df, t_r):
    Y = df['quality']
    df.drop(['quality'],axis=1)
    X_train, X_test, Y_train, Y_test = train_test_split(df, Y, test_size=1-t_r, random_state=124)

    
    return X_train.values, Y_train, X_test.values, Y_test
#####################################################

# %%
x_train, y_train, x_test, y_test = generate_data(white_wine, 0.7)

# %%
display(x_train)
display(y_train)
display(x_test)
display(y_test)
# Out:
# array([[ 6.3 ,  0.29,  0.28, ...,  0.56, 12.7 ,  8.  ],
#        [ 8.8 ,  0.23,  0.35, ...,  0.49,  9.1 ,  6.  ],
#        [ 7.6 ,  0.47,  0.49, ...,  0.51,  9.2 ,  5.  ],
#        ...,
#        [ 6.7 ,  0.27,  0.31, ...,  0.56,  9.6 ,  5.  ],
#        [ 5.9 ,  0.26,  0.29, ...,  0.41, 11.4 ,  6.  ],
#        [ 5.9 ,  0.21,  0.23, ...,  0.59, 10.9 ,  6.  ]])
# 3421    8
# 1902    6
# 1638    5
# 1334    6
# 3995    5
#        ..
# 681     5
# 962     6
# 135     5
# 4764    6
# 4558    6
# Name: quality, Length: 3428, dtype: int64
# array([[ 7.  ,  0.24,  0.32, ...,  0.42, 11.2 ,  8.  ],
#        [ 5.1 ,  0.33,  0.22, ...,  0.38, 12.5 ,  7.  ],
#        [ 6.2 ,  0.33,  0.29, ...,  0.64,  9.5 ,  5.  ],
#        ...,
#        [ 8.  ,  0.26,  0.36, ...,  0.72, 11.6 ,  7.  ],
#        [ 7.  ,  0.35,  0.24, ...,  0.38, 11.  ,  5.  ],
#        [ 7.2 ,  0.33,  0.28, ...,  0.57, 10.6 ,  6.  ]])
# 1087    8
# 375     7
# 1385    5
# 4485    6
# 262     5
#        ..
# 3323    6
# 4630    7
# 1060    7
# 2130    5
# 4708    6
# Name: quality, Length: 1470, dtype: int64

# %%
import matplotlib.pyplot as mat

def visualization(history):
    mat.plot(history.history['acc'])
    mat.plot(history.history['val_acc'])
    mat.title('model accuracy graph')
    mat.xlabel('epoch')
    mat.ylabel('accuracy')
    mat.legend(['Train', 'val'], loc='upper left')
    mat.show()

    mat.plot(history.history['loss'])
    mat.plot(history.history['val_loss'])
    mat.title('model loss graph')
    mat.xlabel('epoch')
    mat.ylabel('loss')
    mat.legend(['Train', 'val'], loc='upper left')
    mat.show()
    
    return

# %%
import matplotlib.pyplot as mat

def visualization_red(history):
    mat.plot(history.history['acc'])
    mat.plot(history.history['val_acc'])
    mat.title('red wine model accuracy graph')
    mat.xlabel('epoch')
    mat.ylabel('accuracy')
    mat.legend(['Train', 'val'], loc='upper left')
    mat.show()

    mat.plot(history.history['loss'])
    mat.plot(history.history['val_loss'])
    mat.title('red wine model loss graph')
    mat.xlabel('epoch')
    mat.ylabel('loss')
    mat.legend(['Train', 'val'], loc='upper left')
    mat.show()
    
    return

# %%
##########################################################
#basic model

X_train, Y_train, X_test, Y_test = generate_data(white_wine, 0.7)
X_train_red, Y_train_red, X_test_red, Y_test_red = generate_data(red_wine, 0.7)

y_train_cat = keras.utils.to_categorical(Y_train, 10)
y_train_cat_red = keras.utils.to_categorical(Y_train_red, 10)

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[12,]))
model.add(keras.layers.Dense(32, activation="relu")) #node 32
model.add(keras.layers.Dense(10, activation="softmax")) #output

model.summary()

model.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history = model.fit(X_train, y_train_cat,batch_size=32,epochs=10,verbose=2,validation_split=0.2)

#visualization
visualization(history)

#red wine
history2 = model.fit(X_train_red, y_train_cat_red,batch_size=32,epochs=10,verbose=2,validation_split=0.2)
visualization_red(history2)
###########################################################
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_49 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 32)                416
# _________________________________________________________________
# dense_105 (Dense)            (None, 10)                330
# =================================================================
# Total params: 746
# Trainable params: 746
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2742 samples, validate on 686 samples
# Epoch 1/10
#  - 1s - loss: 10.0124 - acc: 0.3060 - val_loss: 4.3755 - val_acc: 0.4373
# Epoch 2/10
#  - 0s - loss: 4.2517 - acc: 0.4435 - val_loss: 4.0690 - val_acc: 0.4927
# Epoch 3/10
#  - 0s - loss: 4.0745 - acc: 0.4876 - val_loss: 3.9652 - val_acc: 0.5452
# Epoch 4/10
#  - 0s - loss: 4.0459 - acc: 0.5011 - val_loss: 4.0002 - val_acc: 0.5306
# Epoch 5/10
#  - 0s - loss: 4.0457 - acc: 0.4989 - val_loss: 3.9298 - val_acc: 0.5671
# Epoch 6/10
#  - 0s - loss: 4.0069 - acc: 0.5182 - val_loss: 3.9462 - val_acc: 0.5496
# Epoch 7/10
#  - 0s - loss: 3.9995 - acc: 0.5321 - val_loss: 3.9343 - val_acc: 0.5816
# Epoch 8/10
#  - 0s - loss: 3.9897 - acc: 0.5314 - val_loss: 3.9392 - val_acc: 0.5583
# Epoch 9/10
#  - 0s - loss: 3.9688 - acc: 0.5511 - val_loss: 3.8913 - val_acc: 0.5816
# Epoch 10/10
#  - 0s - loss: 3.9563 - acc: 0.5646 - val_loss: 3.8815 - val_acc: 0.5787
# Train on 895 samples, validate on 224 samples
# Epoch 1/10
#  - 0s - loss: 2.4128 - acc: 0.5341 - val_loss: 1.5744 - val_acc: 0.4911
# Epoch 2/10
#  - 0s - loss: 1.5146 - acc: 0.5073 - val_loss: 1.3866 - val_acc: 0.5312
# Epoch 3/10
#  - 0s - loss: 1.1944 - acc: 0.5430 - val_loss: 1.2676 - val_acc: 0.5536
# Epoch 4/10
#  - 0s - loss: 1.1062 - acc: 0.5966 - val_loss: 1.1876 - val_acc: 0.5491
# Epoch 5/10
#  - 0s - loss: 1.0411 - acc: 0.6291 - val_loss: 1.1199 - val_acc: 0.6027
# Epoch 6/10
#  - 0s - loss: 1.0166 - acc: 0.6324 - val_loss: 1.1193 - val_acc: 0.5893
# Epoch 7/10
#  - 0s - loss: 1.0069 - acc: 0.6380 - val_loss: 1.1344 - val_acc: 0.6205
# Epoch 8/10
#  - 0s - loss: 0.9969 - acc: 0.6402 - val_loss: 1.1234 - val_acc: 0.6295
# Epoch 9/10
#  - 0s - loss: 0.9680 - acc: 0.6860 - val_loss: 1.0747 - val_acc: 0.6250
# Epoch 10/10
#  - 0s - loss: 0.9731 - acc: 0.6514 - val_loss: 1.0686 - val_acc: 0.6161

# %% [markdown]
# model improvement
#     * ex) layer number, node number, Learning rate
#     * ex) Dropout, Normalization

# %%
##########################################################
#hyper parameter
node = 32
epoch_num = 10
bsize = 32

#model_squ_epoch change epoch_num
epoch_num = 30
model_seq_epoch = keras.models.Sequential()
model_seq_epoch.add(keras.layers.Flatten(input_shape=[12,]))
model_seq_epoch.add(keras.layers.Dense(node, activation="relu")) #node 32
model_seq_epoch.add(keras.layers.Dense(10, activation="softmax")) #output

model_seq_epoch.summary()

model_seq_epoch.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history = model_seq_epoch.fit(X_train, y_train_cat,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)

#visualization
visualization(history)

#red wine
history2 = model_seq_epoch.fit(X_train_red, y_train_cat_red,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)
visualization_red(history2)
###########################################################
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_45 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_94 (Dense)             (None, 32)                416
# _________________________________________________________________
# dense_95 (Dense)             (None, 10)                330
# =================================================================
# Total params: 746
# Trainable params: 746
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2742 samples, validate on 686 samples
# Epoch 1/30
#  - 1s - loss: 9.9002 - acc: 0.3147 - val_loss: 8.1617 - val_acc: 0.4650
# Epoch 2/30
#  - 0s - loss: 8.5441 - acc: 0.4354 - val_loss: 8.0943 - val_acc: 0.4679
# Epoch 3/30
#  - 0s - loss: 8.1404 - acc: 0.4322 - val_loss: 5.0551 - val_acc: 0.4475
# Epoch 4/30
#  - 0s - loss: 1.6093 - acc: 0.4063 - val_loss: 1.2665 - val_acc: 0.4767
# Epoch 5/30
#  - 0s - loss: 1.2779 - acc: 0.4460 - val_loss: 1.2654 - val_acc: 0.4504
# Epoch 6/30
#  - 0s - loss: 1.2262 - acc: 0.4774 - val_loss: 1.2042 - val_acc: 0.4213
# Epoch 7/30
#  - 0s - loss: 1.2001 - acc: 0.4927 - val_loss: 1.1497 - val_acc: 0.5554
# Epoch 8/30
#  - 0s - loss: 1.1775 - acc: 0.5069 - val_loss: 1.1182 - val_acc: 0.5700
# Epoch 9/30
#  - 0s - loss: 1.1588 - acc: 0.5120 - val_loss: 1.1534 - val_acc: 0.4606
# Epoch 10/30
#  - 0s - loss: 1.1492 - acc: 0.5113 - val_loss: 1.1050 - val_acc: 0.5758
# Epoch 11/30
#  - 0s - loss: 1.1260 - acc: 0.5416 - val_loss: 1.0877 - val_acc: 0.5889
# Epoch 12/30
#  - 0s - loss: 1.1105 - acc: 0.5346 - val_loss: 1.0889 - val_acc: 0.5131
# Epoch 13/30
#  - 0s - loss: 1.1089 - acc: 0.5274 - val_loss: 1.0599 - val_acc: 0.5991
# Epoch 14/30
#  - 0s - loss: 1.0792 - acc: 0.5562 - val_loss: 1.0510 - val_acc: 0.6122
# Epoch 15/30
#  - 0s - loss: 1.0649 - acc: 0.5762 - val_loss: 1.0433 - val_acc: 0.5845
# Epoch 16/30
#  - 0s - loss: 1.0612 - acc: 0.5638 - val_loss: 1.0310 - val_acc: 0.6137
# Epoch 17/30
#  - 0s - loss: 1.0425 - acc: 0.5850 - val_loss: 1.0023 - val_acc: 0.6356
# Epoch 18/30
#  - 0s - loss: 1.0207 - acc: 0.6116 - val_loss: 1.0112 - val_acc: 0.6108
# Epoch 19/30
#  - 0s - loss: 1.0071 - acc: 0.5974 - val_loss: 0.9808 - val_acc: 0.6501
# Epoch 20/30
#  - 0s - loss: 0.9934 - acc: 0.6207 - val_loss: 1.0156 - val_acc: 0.5583
# Epoch 21/30
#  - 0s - loss: 0.9826 - acc: 0.6196 - val_loss: 1.0066 - val_acc: 0.5918
# Epoch 22/30
#  - 0s - loss: 0.9663 - acc: 0.6404 - val_loss: 0.9316 - val_acc: 0.6735
# Epoch 23/30
#  - 0s - loss: 0.9365 - acc: 0.6623 - val_loss: 0.9369 - val_acc: 0.5364
# Epoch 24/30
#  - 0s - loss: 0.9360 - acc: 0.6510 - val_loss: 0.8964 - val_acc: 0.6793
# Epoch 25/30
#  - 0s - loss: 0.9052 - acc: 0.6718 - val_loss: 0.8921 - val_acc: 0.7041
# Epoch 26/30
#  - 0s - loss: 0.8800 - acc: 0.7064 - val_loss: 0.8561 - val_acc: 0.7274
# Epoch 27/30
#  - 0s - loss: 0.8647 - acc: 0.7188 - val_loss: 0.8559 - val_acc: 0.6079
# Epoch 28/30
#  - 0s - loss: 0.8493 - acc: 0.6955 - val_loss: 0.8785 - val_acc: 0.6851
# Epoch 29/30
#  - 0s - loss: 0.8368 - acc: 0.7192 - val_loss: 0.8415 - val_acc: 0.7201
# Epoch 30/30
#  - 0s - loss: 0.8257 - acc: 0.7367 - val_loss: 0.7946 - val_acc: 0.7376
# Train on 895 samples, validate on 224 samples
# Epoch 1/30
#  - 0s - loss: 0.8614 - acc: 0.7453 - val_loss: 0.9039 - val_acc: 0.7143
# Epoch 2/30
#  - 0s - loss: 0.7789 - acc: 0.7318 - val_loss: 0.8645 - val_acc: 0.7411
# Epoch 3/30
#  - 0s - loss: 0.7556 - acc: 0.7654 - val_loss: 0.8479 - val_acc: 0.7500
# Epoch 4/30
#  - 0s - loss: 0.7381 - acc: 0.7877 - val_loss: 0.8367 - val_acc: 0.7321
# Epoch 5/30
#  - 0s - loss: 0.7306 - acc: 0.7698 - val_loss: 0.8302 - val_acc: 0.7500
# Epoch 6/30
#  - 0s - loss: 0.7126 - acc: 0.7765 - val_loss: 0.8174 - val_acc: 0.7589
# Epoch 7/30
#  - 0s - loss: 0.7017 - acc: 0.7866 - val_loss: 0.8052 - val_acc: 0.7768
# Epoch 8/30
#  - 0s - loss: 0.6945 - acc: 0.8000 - val_loss: 0.7979 - val_acc: 0.8036
# Epoch 9/30
#  - 0s - loss: 0.6919 - acc: 0.8067 - val_loss: 0.7925 - val_acc: 0.7812
# Epoch 10/30
#  - 0s - loss: 0.6818 - acc: 0.8179 - val_loss: 0.7890 - val_acc: 0.7634
# Epoch 11/30
#  - 0s - loss: 0.6712 - acc: 0.8112 - val_loss: 0.7740 - val_acc: 0.7991
# Epoch 12/30
#  - 0s - loss: 0.6603 - acc: 0.8145 - val_loss: 0.7745 - val_acc: 0.7857
# Epoch 13/30
#  - 0s - loss: 0.6522 - acc: 0.8101 - val_loss: 0.7650 - val_acc: 0.7812
# Epoch 14/30
#  - 0s - loss: 0.6464 - acc: 0.8156 - val_loss: 0.7601 - val_acc: 0.7857
# Epoch 15/30
#  - 0s - loss: 0.6414 - acc: 0.8145 - val_loss: 0.7555 - val_acc: 0.8259
# Epoch 16/30
#  - 0s - loss: 0.6331 - acc: 0.8246 - val_loss: 0.7502 - val_acc: 0.8080
# Epoch 17/30
#  - 0s - loss: 0.6267 - acc: 0.8324 - val_loss: 0.7414 - val_acc: 0.7679
# Epoch 18/30
#  - 0s - loss: 0.6199 - acc: 0.8369 - val_loss: 0.7300 - val_acc: 0.7768
# Epoch 19/30
#  - 0s - loss: 0.6070 - acc: 0.8346 - val_loss: 0.7212 - val_acc: 0.8259
# Epoch 20/30
#  - 0s - loss: 0.6055 - acc: 0.8503 - val_loss: 0.7275 - val_acc: 0.8304
# Epoch 21/30
#  - 0s - loss: 0.5992 - acc: 0.8536 - val_loss: 0.7123 - val_acc: 0.8170
# Epoch 22/30
#  - 0s - loss: 0.5952 - acc: 0.8413 - val_loss: 0.7307 - val_acc: 0.8482
# Epoch 23/30
#  - 0s - loss: 0.5889 - acc: 0.8525 - val_loss: 0.7122 - val_acc: 0.8393
# Epoch 24/30
#  - 0s - loss: 0.5829 - acc: 0.8603 - val_loss: 0.7035 - val_acc: 0.8125
# Epoch 25/30
#  - 0s - loss: 0.5801 - acc: 0.8704 - val_loss: 0.6890 - val_acc: 0.7946
# Epoch 26/30
#  - 0s - loss: 0.5690 - acc: 0.8626 - val_loss: 0.6882 - val_acc: 0.8259
# Epoch 27/30
#  - 0s - loss: 0.5637 - acc: 0.8749 - val_loss: 0.6825 - val_acc: 0.8214
# Epoch 28/30
#  - 0s - loss: 0.5597 - acc: 0.8603 - val_loss: 0.6803 - val_acc: 0.8705
# Epoch 29/30
#  - 0s - loss: 0.5527 - acc: 0.8637 - val_loss: 0.6725 - val_acc: 0.8571
# Epoch 30/30
#  - 0s - loss: 0.5501 - acc: 0.8860 - val_loss: 0.6768 - val_acc: 0.8170

# %%
##########################################################
#model_squ_node change node 32 to 64
node = 64
model_squ_node = keras.models.Sequential()
model_squ_node.add(keras.layers.Flatten(input_shape=[12,]))
model_squ_node.add(keras.layers.Dense(node, activation="relu")) #node 32
model_squ_node.add(keras.layers.Dense(10, activation="softmax")) #output

model_squ_node.summary()

model_squ_node.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history = model_squ_node.fit(X_train, y_train_cat,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)

#visualization
visualization(history)

#red wine
history2 = model_squ_node.fit(X_train_red, y_train_cat_red,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)
visualization_red(history2)
###########################################################
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_46 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_96 (Dense)             (None, 64)                832
# _________________________________________________________________
# dense_97 (Dense)             (None, 10)                650
# =================================================================
# Total params: 1,482
# Trainable params: 1,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2742 samples, validate on 686 samples
# Epoch 1/30
#  - 1s - loss: 13.0294 - acc: 0.1251 - val_loss: 8.7714 - val_acc: 0.3338
# Epoch 2/30
#  - 0s - loss: 3.6923 - acc: 0.4201 - val_loss: 1.3748 - val_acc: 0.4796
# Epoch 3/30
#  - 0s - loss: 1.3141 - acc: 0.4438 - val_loss: 1.2697 - val_acc: 0.3819
# Epoch 4/30
#  - 0s - loss: 1.2049 - acc: 0.4931 - val_loss: 1.1607 - val_acc: 0.5962
# Epoch 5/30
#  - 0s - loss: 1.1647 - acc: 0.5040 - val_loss: 1.1278 - val_acc: 0.5350
# Epoch 6/30
#  - 0s - loss: 1.1450 - acc: 0.5058 - val_loss: 1.1448 - val_acc: 0.5073
# Epoch 7/30
#  - 0s - loss: 1.1313 - acc: 0.5212 - val_loss: 1.0891 - val_acc: 0.5904
# Epoch 8/30
#  - 0s - loss: 1.0770 - acc: 0.5547 - val_loss: 1.0502 - val_acc: 0.5933
# Epoch 9/30
#  - 0s - loss: 1.0874 - acc: 0.5350 - val_loss: 1.0235 - val_acc: 0.5977
# Epoch 10/30
#  - 0s - loss: 1.0519 - acc: 0.5671 - val_loss: 1.0005 - val_acc: 0.6268
# Epoch 11/30
#  - 0s - loss: 1.0233 - acc: 0.5890 - val_loss: 1.0286 - val_acc: 0.5787
# Epoch 12/30
#  - 0s - loss: 0.9949 - acc: 0.6032 - val_loss: 0.9495 - val_acc: 0.6370
# Epoch 13/30
#  - 0s - loss: 0.9782 - acc: 0.6163 - val_loss: 0.9658 - val_acc: 0.6983
# Epoch 14/30
#  - 0s - loss: 0.9587 - acc: 0.6368 - val_loss: 0.9321 - val_acc: 0.6472
# Epoch 15/30
#  - 0s - loss: 0.9409 - acc: 0.6473 - val_loss: 1.0052 - val_acc: 0.4810
# Epoch 16/30
#  - 0s - loss: 0.9308 - acc: 0.6408 - val_loss: 0.8804 - val_acc: 0.6851
# Epoch 17/30
#  - 0s - loss: 0.9048 - acc: 0.6612 - val_loss: 0.8473 - val_acc: 0.7274
# Epoch 18/30
#  - 0s - loss: 0.8982 - acc: 0.6568 - val_loss: 0.8511 - val_acc: 0.6370
# Epoch 19/30
#  - 0s - loss: 0.8700 - acc: 0.6758 - val_loss: 0.8202 - val_acc: 0.6531
# Epoch 20/30
#  - 0s - loss: 0.8397 - acc: 0.6991 - val_loss: 0.8358 - val_acc: 0.6720
# Epoch 21/30
#  - 0s - loss: 0.8329 - acc: 0.7082 - val_loss: 0.7898 - val_acc: 0.7230
# Epoch 22/30
#  - 0s - loss: 0.8316 - acc: 0.6802 - val_loss: 0.7871 - val_acc: 0.8294
# Epoch 23/30
#  - 0s - loss: 0.7837 - acc: 0.7290 - val_loss: 0.7425 - val_acc: 0.8120
# Epoch 24/30
#  - 0s - loss: 0.7594 - acc: 0.7648 - val_loss: 0.8032 - val_acc: 0.6443
# Epoch 25/30
#  - 0s - loss: 0.7486 - acc: 0.7710 - val_loss: 0.7440 - val_acc: 0.7230
# Epoch 26/30
#  - 0s - loss: 0.7175 - acc: 0.8012 - val_loss: 0.7413 - val_acc: 0.7172
# Epoch 27/30
#  - 0s - loss: 0.6995 - acc: 0.7885 - val_loss: 0.6818 - val_acc: 0.8222
# Epoch 28/30
#  - 0s - loss: 0.6897 - acc: 0.8016 - val_loss: 0.6672 - val_acc: 0.8134
# Epoch 29/30
#  - 0s - loss: 0.6810 - acc: 0.7958 - val_loss: 0.6485 - val_acc: 0.8163
# Epoch 30/30
#  - 0s - loss: 0.6482 - acc: 0.8151 - val_loss: 0.6326 - val_acc: 0.8921
# Train on 895 samples, validate on 224 samples
# Epoch 1/30
#  - 0s - loss: 0.7140 - acc: 0.7743 - val_loss: 0.7478 - val_acc: 0.7768
# Epoch 2/30
#  - 0s - loss: 0.5979 - acc: 0.8458 - val_loss: 0.7074 - val_acc: 0.8080
# Epoch 3/30
#  - 0s - loss: 0.5733 - acc: 0.8693 - val_loss: 0.6921 - val_acc: 0.8438
# Epoch 4/30
#  - 0s - loss: 0.5517 - acc: 0.8771 - val_loss: 0.6576 - val_acc: 0.8482
# Epoch 5/30
#  - 0s - loss: 0.5359 - acc: 0.8816 - val_loss: 0.6516 - val_acc: 0.8438
# Epoch 6/30
#  - 0s - loss: 0.5277 - acc: 0.8983 - val_loss: 0.6377 - val_acc: 0.8348
# Epoch 7/30
#  - 0s - loss: 0.5130 - acc: 0.8894 - val_loss: 0.6297 - val_acc: 0.8393
# Epoch 8/30
#  - 0s - loss: 0.5031 - acc: 0.8961 - val_loss: 0.6276 - val_acc: 0.8482
# Epoch 9/30
#  - 0s - loss: 0.4972 - acc: 0.9061 - val_loss: 0.6357 - val_acc: 0.8616
# Epoch 10/30
#  - 0s - loss: 0.4977 - acc: 0.9095 - val_loss: 0.6150 - val_acc: 0.8214
# Epoch 11/30
#  - 0s - loss: 0.4794 - acc: 0.9073 - val_loss: 0.5983 - val_acc: 0.8795
# Epoch 12/30
#  - 0s - loss: 0.4701 - acc: 0.9128 - val_loss: 0.5933 - val_acc: 0.8973
# Epoch 13/30
#  - 0s - loss: 0.4632 - acc: 0.9140 - val_loss: 0.5793 - val_acc: 0.8616
# Epoch 14/30
#  - 0s - loss: 0.4526 - acc: 0.9196 - val_loss: 0.5729 - val_acc: 0.8884
# Epoch 15/30
#  - 0s - loss: 0.4498 - acc: 0.9117 - val_loss: 0.5678 - val_acc: 0.8750
# Epoch 16/30
#  - 0s - loss: 0.4400 - acc: 0.9196 - val_loss: 0.5586 - val_acc: 0.8884
# Epoch 17/30
#  - 0s - loss: 0.4380 - acc: 0.9296 - val_loss: 0.5586 - val_acc: 0.9018
# Epoch 18/30
#  - 0s - loss: 0.4335 - acc: 0.9218 - val_loss: 0.5535 - val_acc: 0.8616
# Epoch 19/30
#  - 0s - loss: 0.4263 - acc: 0.9196 - val_loss: 0.5395 - val_acc: 0.8616
# Epoch 20/30
#  - 0s - loss: 0.4160 - acc: 0.9263 - val_loss: 0.5257 - val_acc: 0.8839
# Epoch 21/30
#  - 0s - loss: 0.4085 - acc: 0.9285 - val_loss: 0.5249 - val_acc: 0.9018
# Epoch 22/30
#  - 0s - loss: 0.4035 - acc: 0.9285 - val_loss: 0.5189 - val_acc: 0.8661
# Epoch 23/30
#  - 0s - loss: 0.3992 - acc: 0.9274 - val_loss: 0.5103 - val_acc: 0.8705
# Epoch 24/30
#  - 0s - loss: 0.3979 - acc: 0.9251 - val_loss: 0.5006 - val_acc: 0.8973
# Epoch 25/30
#  - 0s - loss: 0.3866 - acc: 0.9218 - val_loss: 0.5195 - val_acc: 0.9018
# Epoch 26/30
#  - 0s - loss: 0.3897 - acc: 0.9341 - val_loss: 0.4937 - val_acc: 0.9018
# Epoch 27/30
#  - 0s - loss: 0.3772 - acc: 0.9307 - val_loss: 0.4897 - val_acc: 0.8929
# Epoch 28/30
#  - 0s - loss: 0.3706 - acc: 0.9330 - val_loss: 0.4799 - val_acc: 0.8929
# Epoch 29/30
#  - 0s - loss: 0.3662 - acc: 0.9318 - val_loss: 0.4757 - val_acc: 0.9018
# Epoch 30/30
#  - 0s - loss: 0.3657 - acc: 0.9397 - val_loss: 0.4729 - val_acc: 0.9018

# %%
##########################################################
#model_squ_layer add 2 hidden layer
model_squ_layer = keras.models.Sequential()
model_squ_layer.add(keras.layers.Flatten(input_shape=[12,]))
model_squ_layer.add(keras.layers.Dense(node, activation="relu"))
model_squ_layer.add(keras.layers.Dense(node, activation="relu"))
model_squ_layer.add(keras.layers.Dense(node, activation="relu"))
model_squ_layer.add(keras.layers.Dense(10, activation="softmax")) #output

model_squ_layer.summary()

model_squ_layer.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history = model_squ_layer.fit(X_train, y_train_cat,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)

#visualization
visualization(history)

#red wine
history2 = model_squ_layer.fit(X_train_red, y_train_cat_red,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)
visualization_red(history2)
###########################################################
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_47 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_98 (Dense)             (None, 64)                832
# _________________________________________________________________
# dense_99 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_100 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_101 (Dense)            (None, 10)                650
# =================================================================
# Total params: 9,802
# Trainable params: 9,802
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2742 samples, validate on 686 samples
# Epoch 1/30
#  - 1s - loss: 2.8186 - acc: 0.3727 - val_loss: 1.2792 - val_acc: 0.4810
# Epoch 2/30
#  - 0s - loss: 1.2989 - acc: 0.4555 - val_loss: 1.2147 - val_acc: 0.5175
# Epoch 3/30
#  - 0s - loss: 1.2508 - acc: 0.4697 - val_loss: 1.3945 - val_acc: 0.4665
# Epoch 4/30
#  - 0s - loss: 1.2399 - acc: 0.4577 - val_loss: 1.1440 - val_acc: 0.5058
# Epoch 5/30
#  - 0s - loss: 1.1834 - acc: 0.4770 - val_loss: 1.1554 - val_acc: 0.4767
# Epoch 6/30
#  - 0s - loss: 1.1221 - acc: 0.5190 - val_loss: 1.1410 - val_acc: 0.5569
# Epoch 7/30
#  - 0s - loss: 1.0637 - acc: 0.5631 - val_loss: 1.0321 - val_acc: 0.5350
# Epoch 8/30
#  - 0s - loss: 0.9566 - acc: 0.6214 - val_loss: 1.0160 - val_acc: 0.5423
# Epoch 9/30
#  - 0s - loss: 0.9195 - acc: 0.6211 - val_loss: 0.7988 - val_acc: 0.7070
# Epoch 10/30
#  - 0s - loss: 0.8375 - acc: 0.6834 - val_loss: 0.7394 - val_acc: 0.7741
# Epoch 11/30
#  - 0s - loss: 0.7556 - acc: 0.7148 - val_loss: 0.6344 - val_acc: 0.8222
# Epoch 12/30
#  - 0s - loss: 0.6490 - acc: 0.7786 - val_loss: 0.5976 - val_acc: 0.8499
# Epoch 13/30
#  - 0s - loss: 0.6008 - acc: 0.7950 - val_loss: 0.5403 - val_acc: 0.7915
# Epoch 14/30
#  - 0s - loss: 0.5717 - acc: 0.7983 - val_loss: 0.5478 - val_acc: 0.7872
# Epoch 15/30
#  - 0s - loss: 0.4747 - acc: 0.8567 - val_loss: 0.4340 - val_acc: 0.9067
# Epoch 16/30
#  - 0s - loss: 0.3982 - acc: 0.9048 - val_loss: 0.3483 - val_acc: 0.9388
# Epoch 17/30
#  - 0s - loss: 0.3641 - acc: 0.9070 - val_loss: 0.2896 - val_acc: 0.9548
# Epoch 18/30
#  - 0s - loss: 0.3058 - acc: 0.9278 - val_loss: 0.2882 - val_acc: 0.9534
# Epoch 19/30
#  - 0s - loss: 0.2761 - acc: 0.9351 - val_loss: 0.2223 - val_acc: 0.9577
# Epoch 20/30
#  - 0s - loss: 0.2475 - acc: 0.9427 - val_loss: 0.3409 - val_acc: 0.9038
# Epoch 21/30
#  - 0s - loss: 0.2074 - acc: 0.9643 - val_loss: 0.1693 - val_acc: 0.9752
# Epoch 22/30
#  - 0s - loss: 0.1675 - acc: 0.9745 - val_loss: 0.1445 - val_acc: 0.9752
# Epoch 23/30
#  - 0s - loss: 0.1768 - acc: 0.9635 - val_loss: 0.1285 - val_acc: 0.9796
# Epoch 24/30
#  - 0s - loss: 0.1286 - acc: 0.9814 - val_loss: 0.1201 - val_acc: 0.9767
# Epoch 25/30
#  - 0s - loss: 0.1846 - acc: 0.9508 - val_loss: 0.1010 - val_acc: 0.9767
# Epoch 26/30
#  - 0s - loss: 0.1081 - acc: 0.9843 - val_loss: 0.1027 - val_acc: 0.9883
# Epoch 27/30
#  - 0s - loss: 0.1115 - acc: 0.9799 - val_loss: 0.0841 - val_acc: 0.9854
# Epoch 28/30
#  - 0s - loss: 0.0916 - acc: 0.9843 - val_loss: 0.0815 - val_acc: 0.9796
# Epoch 29/30
#  - 0s - loss: 0.0778 - acc: 0.9902 - val_loss: 0.0607 - val_acc: 0.9883
# Epoch 30/30
#  - 0s - loss: 0.0811 - acc: 0.9865 - val_loss: 0.0810 - val_acc: 0.9752
# Train on 895 samples, validate on 224 samples
# Epoch 1/30
#  - 0s - loss: 0.2634 - acc: 0.9140 - val_loss: 0.1642 - val_acc: 0.9688
# Epoch 2/30
#  - 0s - loss: 0.1018 - acc: 0.9799 - val_loss: 0.1001 - val_acc: 0.9732
# Epoch 3/30
#  - 0s - loss: 0.0875 - acc: 0.9844 - val_loss: 0.1103 - val_acc: 0.9643
# Epoch 4/30
#  - 0s - loss: 0.0728 - acc: 0.9866 - val_loss: 0.0752 - val_acc: 0.9821
# Epoch 5/30
#  - 0s - loss: 0.0582 - acc: 0.9911 - val_loss: 0.0652 - val_acc: 0.9955
# Epoch 6/30
#  - 0s - loss: 0.0523 - acc: 0.9911 - val_loss: 0.0560 - val_acc: 0.9955
# Epoch 7/30
#  - 0s - loss: 0.0449 - acc: 0.9955 - val_loss: 0.0546 - val_acc: 0.9866
# Epoch 8/30
#  - 0s - loss: 0.0419 - acc: 0.9933 - val_loss: 0.0443 - val_acc: 0.9955
# Epoch 9/30
#  - 0s - loss: 0.0378 - acc: 0.9989 - val_loss: 0.0444 - val_acc: 0.9911
# Epoch 10/30
#  - 0s - loss: 0.0357 - acc: 0.9978 - val_loss: 0.0505 - val_acc: 0.9911
# Epoch 11/30
#  - 0s - loss: 0.0333 - acc: 0.9944 - val_loss: 0.0390 - val_acc: 1.0000
# Epoch 12/30
#  - 0s - loss: 0.0304 - acc: 0.9989 - val_loss: 0.0369 - val_acc: 0.9955
# Epoch 13/30
#  - 0s - loss: 0.0290 - acc: 0.9989 - val_loss: 0.0446 - val_acc: 0.9911
# Epoch 14/30
#  - 0s - loss: 0.0264 - acc: 0.9989 - val_loss: 0.0305 - val_acc: 1.0000
# Epoch 15/30
#  - 0s - loss: 0.0278 - acc: 0.9978 - val_loss: 0.0421 - val_acc: 0.9911
# Epoch 16/30
#  - 0s - loss: 0.0243 - acc: 0.9989 - val_loss: 0.0317 - val_acc: 0.9955
# Epoch 17/30
#  - 0s - loss: 0.0214 - acc: 1.0000 - val_loss: 0.0335 - val_acc: 0.9955
# Epoch 18/30
#  - 0s - loss: 0.0231 - acc: 1.0000 - val_loss: 0.0291 - val_acc: 0.9955
# Epoch 19/30
#  - 0s - loss: 0.0213 - acc: 0.9989 - val_loss: 0.0346 - val_acc: 0.9911
# Epoch 20/30
#  - 0s - loss: 0.0186 - acc: 1.0000 - val_loss: 0.0285 - val_acc: 0.9955
# Epoch 21/30
#  - 0s - loss: 0.0182 - acc: 1.0000 - val_loss: 0.0316 - val_acc: 0.9955
# Epoch 22/30
#  - 0s - loss: 0.0172 - acc: 1.0000 - val_loss: 0.0278 - val_acc: 0.9955
# Epoch 23/30
#  - 0s - loss: 0.0166 - acc: 1.0000 - val_loss: 0.0227 - val_acc: 0.9955
# Epoch 24/30
#  - 0s - loss: 0.0158 - acc: 1.0000 - val_loss: 0.0260 - val_acc: 0.9955
# Epoch 25/30
#  - 0s - loss: 0.0160 - acc: 0.9989 - val_loss: 0.0277 - val_acc: 0.9955
# Epoch 26/30
#  - 0s - loss: 0.0139 - acc: 1.0000 - val_loss: 0.0261 - val_acc: 0.9955
# Epoch 27/30
#  - 0s - loss: 0.0136 - acc: 1.0000 - val_loss: 0.0222 - val_acc: 0.9955
# Epoch 28/30
#  - 0s - loss: 0.0124 - acc: 1.0000 - val_loss: 0.0271 - val_acc: 0.9955
# Epoch 29/30
#  - 0s - loss: 0.0127 - acc: 1.0000 - val_loss: 0.0202 - val_acc: 0.9955
# Epoch 30/30
#  - 0s - loss: 0.0109 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 0.9955

# %%
##########################################################
#model_squ_normal use batchnormalization
model_squ_normal = keras.models.Sequential()
model_squ_normal.add(keras.layers.Flatten(input_shape=[12,]))

model_squ_normal.add(keras.layers.Dense(node))
model_squ_normal.add(keras.layers.BatchNormalization())
model_squ_normal.add(keras.layers.Activation('relu'))
model_squ_normal.add(keras.layers.Dense(node))
model_squ_normal.add(keras.layers.BatchNormalization())
model_squ_normal.add(keras.layers.Activation('relu'))
model_squ_normal.add(keras.layers.Dense(node))
model_squ_normal.add(keras.layers.BatchNormalization())
model_squ_normal.add(keras.layers.Activation('relu'))

model_squ_normal.add(keras.layers.Dense(10, activation="softmax")) #output

model_squ_normal.summary()

model_squ_normal.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history = model_squ_normal.fit(X_train, y_train_cat,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)

#visualization
visualization(history)

#red wine
history2 = model_squ_normal.fit(X_train_red, y_train_cat_red,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)
visualization_red(history2)
###########################################################
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_54 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_122 (Dense)            (None, 64)                832
# _________________________________________________________________
# batch_normalization_v1_19 (B (None, 64)                256
# _________________________________________________________________
# activation_19 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_123 (Dense)            (None, 64)                4160
# _________________________________________________________________
# batch_normalization_v1_20 (B (None, 64)                256
# _________________________________________________________________
# activation_20 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_124 (Dense)            (None, 64)                4160
# _________________________________________________________________
# batch_normalization_v1_21 (B (None, 64)                256
# _________________________________________________________________
# activation_21 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_125 (Dense)            (None, 10)                650
# =================================================================
# Total params: 10,570
# Trainable params: 10,186
# Non-trainable params: 384
# _________________________________________________________________
# Train on 2742 samples, validate on 686 samples
# Epoch 1/30
#  - 2s - loss: 1.6678 - acc: 0.4179 - val_loss: 1.5135 - val_acc: 0.4898
# Epoch 2/30
#  - 0s - loss: 0.9393 - acc: 0.6645 - val_loss: 1.3330 - val_acc: 0.4563
# Epoch 3/30
#  - 0s - loss: 0.5146 - acc: 0.8479 - val_loss: 1.0826 - val_acc: 0.5306
# Epoch 4/30
#  - 0s - loss: 0.2524 - acc: 0.9347 - val_loss: 1.2437 - val_acc: 0.4198
# Epoch 5/30
#  - 0s - loss: 0.1642 - acc: 0.9588 - val_loss: 0.5144 - val_acc: 0.8411
# Epoch 6/30
#  - 0s - loss: 0.1376 - acc: 0.9643 - val_loss: 0.1336 - val_acc: 0.9913
# Epoch 7/30
#  - 0s - loss: 0.1183 - acc: 0.9646 - val_loss: 0.1614 - val_acc: 0.9883
# Epoch 8/30
#  - 0s - loss: 0.0775 - acc: 0.9796 - val_loss: 0.1491 - val_acc: 0.9840
# Epoch 9/30
#  - 0s - loss: 0.1014 - acc: 0.9657 - val_loss: 0.1838 - val_acc: 0.9461
# Epoch 10/30
#  - 0s - loss: 0.1094 - acc: 0.9621 - val_loss: 0.0641 - val_acc: 0.9810
# Epoch 11/30
#  - 0s - loss: 0.1056 - acc: 0.9643 - val_loss: 0.3059 - val_acc: 0.8192
# Epoch 12/30
#  - 0s - loss: 0.1008 - acc: 0.9672 - val_loss: 0.1325 - val_acc: 0.9913
# Epoch 13/30
#  - 0s - loss: 0.0817 - acc: 0.9723 - val_loss: 0.4019 - val_acc: 0.8805
# Epoch 14/30
#  - 0s - loss: 0.0770 - acc: 0.9723 - val_loss: 0.0277 - val_acc: 0.9913
# Epoch 15/30
#  - 0s - loss: 0.0810 - acc: 0.9716 - val_loss: 0.6080 - val_acc: 0.7157
# Epoch 16/30
#  - 0s - loss: 0.0543 - acc: 0.9821 - val_loss: 0.0152 - val_acc: 0.9956
# Epoch 17/30
#  - 0s - loss: 0.0585 - acc: 0.9818 - val_loss: 0.0409 - val_acc: 0.9956
# Epoch 18/30
#  - 0s - loss: 0.0472 - acc: 0.9865 - val_loss: 0.0116 - val_acc: 0.9942
# Epoch 19/30
#  - 0s - loss: 0.0633 - acc: 0.9770 - val_loss: 0.0624 - val_acc: 0.9781
# Epoch 20/30
#  - 0s - loss: 0.0757 - acc: 0.9741 - val_loss: 0.4747 - val_acc: 0.8324
# Epoch 21/30
#  - 0s - loss: 0.0571 - acc: 0.9832 - val_loss: 0.0162 - val_acc: 0.9971
# Epoch 22/30
#  - 0s - loss: 0.0717 - acc: 0.9737 - val_loss: 2.9132 - val_acc: 0.3703
# Epoch 23/30
#  - 0s - loss: 0.0371 - acc: 0.9876 - val_loss: 0.0090 - val_acc: 0.9956
# Epoch 24/30
#  - 0s - loss: 0.0496 - acc: 0.9840 - val_loss: 0.0169 - val_acc: 0.9956
# Epoch 25/30
#  - 0s - loss: 0.0408 - acc: 0.9883 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 26/30
#  - 0s - loss: 0.0534 - acc: 0.9799 - val_loss: 0.0075 - val_acc: 0.9985
# Epoch 27/30
#  - 0s - loss: 0.0450 - acc: 0.9880 - val_loss: 0.0135 - val_acc: 1.0000
# Epoch 28/30
#  - 0s - loss: 0.0302 - acc: 0.9909 - val_loss: 0.0152 - val_acc: 1.0000
# Epoch 29/30
#  - 0s - loss: 0.0733 - acc: 0.9770 - val_loss: 0.5331 - val_acc: 0.7391
# Epoch 30/30
#  - 0s - loss: 0.0505 - acc: 0.9832 - val_loss: 0.0087 - val_acc: 0.9985
# Train on 895 samples, validate on 224 samples
# Epoch 1/30
#  - 0s - loss: 0.2151 - acc: 0.9374 - val_loss: 0.7305 - val_acc: 0.8527
# Epoch 2/30
#  - 0s - loss: 0.0267 - acc: 0.9955 - val_loss: 0.0593 - val_acc: 1.0000
# Epoch 3/30
#  - 0s - loss: 0.0136 - acc: 0.9966 - val_loss: 0.0143 - val_acc: 1.0000
# Epoch 4/30
#  - 0s - loss: 0.0136 - acc: 0.9966 - val_loss: 0.0112 - val_acc: 1.0000
# Epoch 5/30
#  - 0s - loss: 0.0096 - acc: 1.0000 - val_loss: 0.0059 - val_acc: 1.0000
# Epoch 6/30
#  - 0s - loss: 0.0194 - acc: 0.9933 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 7/30
#  - 0s - loss: 0.0245 - acc: 0.9911 - val_loss: 0.0050 - val_acc: 1.0000
# Epoch 8/30
#  - 0s - loss: 0.0148 - acc: 0.9978 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 9/30
#  - 0s - loss: 0.0189 - acc: 0.9978 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 10/30
#  - 0s - loss: 0.0192 - acc: 0.9911 - val_loss: 0.0049 - val_acc: 1.0000
# Epoch 11/30
#  - 0s - loss: 0.0162 - acc: 0.9944 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 12/30
#  - 0s - loss: 0.0125 - acc: 0.9955 - val_loss: 0.0037 - val_acc: 1.0000
# Epoch 13/30
#  - 0s - loss: 0.0116 - acc: 0.9966 - val_loss: 0.0044 - val_acc: 1.0000
# Epoch 14/30
#  - 0s - loss: 0.0192 - acc: 0.9922 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 15/30
#  - 0s - loss: 0.0398 - acc: 0.9877 - val_loss: 0.0983 - val_acc: 0.9732
# Epoch 16/30
#  - 0s - loss: 0.0179 - acc: 0.9944 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 17/30
#  - 0s - loss: 0.0176 - acc: 0.9922 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 18/30
#  - 0s - loss: 0.0110 - acc: 0.9966 - val_loss: 0.0048 - val_acc: 1.0000
# Epoch 19/30
#  - 0s - loss: 0.0052 - acc: 0.9989 - val_loss: 0.0032 - val_acc: 1.0000
# Epoch 20/30
#  - 0s - loss: 0.0468 - acc: 0.9788 - val_loss: 0.0133 - val_acc: 0.9955
# Epoch 21/30
#  - 0s - loss: 0.0485 - acc: 0.9799 - val_loss: 0.0685 - val_acc: 0.9688
# Epoch 22/30
#  - 0s - loss: 0.0462 - acc: 0.9899 - val_loss: 0.0527 - val_acc: 0.9866
# Epoch 23/30
#  - 0s - loss: 0.0181 - acc: 0.9955 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 24/30
#  - 0s - loss: 0.0062 - acc: 1.0000 - val_loss: 0.0035 - val_acc: 1.0000
# Epoch 25/30
#  - 0s - loss: 0.0101 - acc: 0.9978 - val_loss: 0.0026 - val_acc: 1.0000
# Epoch 26/30
#  - 0s - loss: 0.0063 - acc: 0.9989 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 27/30
#  - 0s - loss: 0.0061 - acc: 1.0000 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 28/30
#  - 0s - loss: 0.0061 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 29/30
#  - 0s - loss: 0.0350 - acc: 0.9866 - val_loss: 0.0174 - val_acc: 0.9955
# Epoch 30/30
#  - 0s - loss: 0.0157 - acc: 0.9911 - val_loss: 0.0020 - val_acc: 1.0000

# %%
##########################################################
#model_squ_dout use drop out
model_squ_dout = keras.models.Sequential()
model_squ_dout.add(keras.layers.Flatten(input_shape=[12,]))

model_squ_dout.add(keras.layers.Dense(node))
model_squ_dout.add(keras.layers.BatchNormalization())
model_squ_dout.add(keras.layers.Activation('relu'))
model_squ_dout.add(keras.layers.Dropout(0.2))
model_squ_dout.add(keras.layers.Dense(node))
model_squ_dout.add(keras.layers.BatchNormalization())
model_squ_dout.add(keras.layers.Activation('relu'))
model_squ_dout.add(keras.layers.Dropout(0.2))
model_squ_dout.add(keras.layers.Dense(node))
model_squ_dout.add(keras.layers.BatchNormalization())
model_squ_dout.add(keras.layers.Activation('relu'))
model_squ_dout.add(keras.layers.Dropout(0.2))

model_squ_dout.add(keras.layers.Dense(10, activation="softmax")) #output

model_squ_dout.summary()

model_squ_dout.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history = model_squ_dout.fit(X_train, y_train_cat,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)

#visualization
visualization(history)

#red wine
history2 = model_squ_dout.fit(X_train_red, y_train_cat_red,batch_size=bsize,epochs=epoch_num,verbose=2,validation_split=0.2)
visualization_red(history2)
###########################################################
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_56 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_130 (Dense)            (None, 64)                832
# _________________________________________________________________
# batch_normalization_v1_25 (B (None, 64)                256
# _________________________________________________________________
# activation_25 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_131 (Dense)            (None, 64)                4160
# _________________________________________________________________
# batch_normalization_v1_26 (B (None, 64)                256
# _________________________________________________________________
# activation_26 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_132 (Dense)            (None, 64)                4160
# _________________________________________________________________
# batch_normalization_v1_27 (B (None, 64)                256
# _________________________________________________________________
# activation_27 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_133 (Dense)            (None, 10)                650
# =================================================================
# Total params: 10,570
# Trainable params: 10,186
# Non-trainable params: 384
# _________________________________________________________________
# Train on 2742 samples, validate on 686 samples
# Epoch 1/30
#  - 2s - loss: 1.9258 - acc: 0.2980 - val_loss: 1.6875 - val_acc: 0.4475
# Epoch 2/30
#  - 0s - loss: 1.4108 - acc: 0.4322 - val_loss: 1.4181 - val_acc: 0.4665
# Epoch 3/30
#  - 0s - loss: 1.2633 - acc: 0.4796 - val_loss: 1.4473 - val_acc: 0.3003
# Epoch 4/30
#  - 0s - loss: 0.9676 - acc: 0.6408 - val_loss: 1.2947 - val_acc: 0.3732
# Epoch 5/30
#  - 0s - loss: 0.7056 - acc: 0.7622 - val_loss: 0.8798 - val_acc: 0.6414
# Epoch 6/30
#  - 0s - loss: 0.5420 - acc: 0.8133 - val_loss: 0.5044 - val_acc: 0.8411
# Epoch 7/30
#  - 0s - loss: 0.4493 - acc: 0.8476 - val_loss: 0.3426 - val_acc: 0.9665
# Epoch 8/30
#  - 0s - loss: 0.3994 - acc: 0.8654 - val_loss: 0.1986 - val_acc: 0.9781
# Epoch 9/30
#  - 0s - loss: 0.3320 - acc: 0.8953 - val_loss: 0.1501 - val_acc: 0.9679
# Epoch 10/30
#  - 0s - loss: 0.3020 - acc: 0.8968 - val_loss: 0.1183 - val_acc: 0.9927
# Epoch 11/30
#  - 0s - loss: 0.2720 - acc: 0.9106 - val_loss: 0.0897 - val_acc: 0.9898
# Epoch 12/30
#  - 0s - loss: 0.2439 - acc: 0.9190 - val_loss: 0.0956 - val_acc: 0.9869
# Epoch 13/30
#  - 0s - loss: 0.1976 - acc: 0.9358 - val_loss: 0.0638 - val_acc: 0.9913
# Epoch 14/30
#  - 0s - loss: 0.2399 - acc: 0.9132 - val_loss: 0.1383 - val_acc: 0.9927
# Epoch 15/30
#  - 0s - loss: 0.2044 - acc: 0.9296 - val_loss: 0.0780 - val_acc: 0.9708
# Epoch 16/30
#  - 0s - loss: 0.2138 - acc: 0.9234 - val_loss: 0.1350 - val_acc: 0.9942
# Epoch 17/30
#  - 0s - loss: 0.1776 - acc: 0.9347 - val_loss: 0.1281 - val_acc: 0.9883
# Epoch 18/30
#  - 0s - loss: 0.1675 - acc: 0.9416 - val_loss: 0.0381 - val_acc: 0.9942
# Epoch 19/30
#  - 0s - loss: 0.1959 - acc: 0.9333 - val_loss: 0.0538 - val_acc: 0.9927
# Epoch 20/30
#  - 0s - loss: 0.1860 - acc: 0.9333 - val_loss: 0.0414 - val_acc: 0.9942
# Epoch 21/30
#  - 0s - loss: 0.1682 - acc: 0.9380 - val_loss: 0.0391 - val_acc: 0.9942
# Epoch 22/30
#  - 0s - loss: 0.1780 - acc: 0.9380 - val_loss: 0.1852 - val_acc: 0.9373
# Epoch 23/30
#  - 0s - loss: 0.1653 - acc: 0.9442 - val_loss: 0.0391 - val_acc: 0.9942
# Epoch 24/30
#  - 0s - loss: 0.1521 - acc: 0.9453 - val_loss: 0.2688 - val_acc: 0.9169
# Epoch 25/30
#  - 0s - loss: 0.1549 - acc: 0.9427 - val_loss: 0.0369 - val_acc: 0.9942
# Epoch 26/30
#  - 0s - loss: 0.1801 - acc: 0.9369 - val_loss: 0.0383 - val_acc: 0.9942
# Epoch 27/30
#  - 0s - loss: 0.1691 - acc: 0.9431 - val_loss: 0.0667 - val_acc: 0.9942
# Epoch 28/30
#  - 0s - loss: 0.1199 - acc: 0.9610 - val_loss: 0.0290 - val_acc: 0.9942
# Epoch 29/30
#  - 0s - loss: 0.1388 - acc: 0.9544 - val_loss: 0.0298 - val_acc: 0.9913
# Epoch 30/30
#  - 0s - loss: 0.1425 - acc: 0.9519 - val_loss: 0.0357 - val_acc: 0.9942
# Train on 895 samples, validate on 224 samples
# Epoch 1/30
#  - 0s - loss: 0.2301 - acc: 0.9196 - val_loss: 0.0767 - val_acc: 0.9643
# Epoch 2/30
#  - 0s - loss: 0.1039 - acc: 0.9642 - val_loss: 0.0820 - val_acc: 0.9643
# Epoch 3/30
#  - 0s - loss: 0.0890 - acc: 0.9676 - val_loss: 0.0746 - val_acc: 0.9643
# Epoch 4/30
#  - 0s - loss: 0.0941 - acc: 0.9777 - val_loss: 0.0670 - val_acc: 0.9643
# Epoch 5/30
#  - 0s - loss: 0.1176 - acc: 0.9587 - val_loss: 0.0517 - val_acc: 0.9643
# Epoch 6/30
#  - 0s - loss: 0.1050 - acc: 0.9598 - val_loss: 0.0477 - val_acc: 0.9643
# Epoch 7/30
#  - 0s - loss: 0.0711 - acc: 0.9754 - val_loss: 0.0585 - val_acc: 0.9643
# Epoch 8/30
#  - 0s - loss: 0.0765 - acc: 0.9732 - val_loss: 0.0419 - val_acc: 0.9866
# Epoch 9/30
#  - 0s - loss: 0.0776 - acc: 0.9743 - val_loss: 0.0448 - val_acc: 0.9643
# Epoch 10/30
#  - 0s - loss: 0.0893 - acc: 0.9743 - val_loss: 0.0463 - val_acc: 0.9688
# Epoch 11/30
#  - 0s - loss: 0.0930 - acc: 0.9631 - val_loss: 0.0381 - val_acc: 0.9777
# Epoch 12/30
#  - 0s - loss: 0.1045 - acc: 0.9575 - val_loss: 0.0415 - val_acc: 0.9688
# Epoch 13/30
#  - 0s - loss: 0.0846 - acc: 0.9698 - val_loss: 0.0448 - val_acc: 0.9688
# Epoch 14/30
#  - 0s - loss: 0.1084 - acc: 0.9564 - val_loss: 0.0453 - val_acc: 0.9688
# Epoch 15/30
#  - 0s - loss: 0.0515 - acc: 0.9855 - val_loss: 0.0370 - val_acc: 0.9777
# Epoch 16/30
#  - 0s - loss: 0.0767 - acc: 0.9721 - val_loss: 0.0370 - val_acc: 0.9821
# Epoch 17/30
#  - 0s - loss: 0.0808 - acc: 0.9687 - val_loss: 0.0349 - val_acc: 0.9821
# Epoch 18/30
#  - 0s - loss: 0.0891 - acc: 0.9732 - val_loss: 0.0339 - val_acc: 0.9911
# Epoch 19/30
#  - 0s - loss: 0.0603 - acc: 0.9743 - val_loss: 0.0310 - val_acc: 0.9866
# Epoch 20/30
#  - 0s - loss: 0.1060 - acc: 0.9575 - val_loss: 0.0417 - val_acc: 0.9732
# Epoch 21/30
#  - 0s - loss: 0.0480 - acc: 0.9832 - val_loss: 0.0493 - val_acc: 0.9643
# Epoch 22/30
#  - 0s - loss: 0.0595 - acc: 0.9821 - val_loss: 0.0489 - val_acc: 0.9643
# Epoch 23/30
#  - 0s - loss: 0.0625 - acc: 0.9810 - val_loss: 0.0497 - val_acc: 0.9643
# Epoch 24/30
#  - 0s - loss: 0.0765 - acc: 0.9743 - val_loss: 0.0326 - val_acc: 0.9911
# Epoch 25/30
#  - 0s - loss: 0.0957 - acc: 0.9654 - val_loss: 0.0411 - val_acc: 0.9688
# Epoch 26/30
#  - 0s - loss: 0.0603 - acc: 0.9810 - val_loss: 0.0375 - val_acc: 0.9821
# Epoch 27/30
#  - 0s - loss: 0.0522 - acc: 0.9832 - val_loss: 0.0535 - val_acc: 0.9643
# Epoch 28/30
#  - 0s - loss: 0.0957 - acc: 0.9665 - val_loss: 0.0430 - val_acc: 0.9643
# Epoch 29/30
#  - 0s - loss: 0.0723 - acc: 0.9721 - val_loss: 0.0392 - val_acc: 0.9777
# Epoch 30/30
#  - 0s - loss: 0.0679 - acc: 0.9743 - val_loss: 0.0284 - val_acc: 0.9911

# %%
##########################################################
#concatenate data frame
white_wine_temp = pd.read_csv("winequality-white.csv")
red_wine_temp = pd.read_csv("winequality-red.csv")

wine = pd.concat([white_wine_temp, red_wine_temp])

display(wine)
###########################################################
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [6497 rows x 12 columns]

# %%
X_train_total, Y_train_total, X_test_total, Y_test_total = generate_data(wine, 0.7)
y_train_label = keras.utils.to_categorical(Y_train, 10)

model_final = keras.models.Sequential()
model_final.add(keras.layers.Flatten(input_shape=[12,]))

model.add(keras.layers.Dense(32, activation="relu"))
model_final.add(keras.layers.Dropout(0.2))

model_final.add(keras.layers.Dense(10, activation="softmax"))

model_final.summary()

model_final.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history_total = model_final.fit(X_train_total, y_train_label,batch_size=32,epochs=10,verbose=2,validation_split=0.2)

visualization(history_total)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_95 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 12)                0
# _________________________________________________________________
# dense_249 (Dense)            (None, 10)                130
# =================================================================
# Total params: 130
# Trainable params: 130
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3637 samples, validate on 910 samples
# Epoch 1/10
#  - 3s - loss: 12.7461 - acc: 0.1114 - val_loss: 8.4972 - val_acc: 0.3813
# Epoch 2/10
#  - 0s - loss: 8.0628 - acc: 0.3434 - val_loss: 5.1932 - val_acc: 0.3143
# Epoch 3/10
#  - 0s - loss: 6.1014 - acc: 0.3187 - val_loss: 4.2744 - val_acc: 0.3110
# Epoch 4/10
#  - 0s - loss: 4.0099 - acc: 0.3060 - val_loss: 1.9570 - val_acc: 0.3714
# Epoch 5/10
#  - 0s - loss: 2.4018 - acc: 0.3024 - val_loss: 1.6270 - val_acc: 0.3802
# Epoch 6/10
#  - 0s - loss: 1.8783 - acc: 0.3118 - val_loss: 1.4173 - val_acc: 0.3967
# Epoch 7/10
#  - 0s - loss: 1.6051 - acc: 0.3536 - val_loss: 1.3517 - val_acc: 0.4538
# Epoch 8/10
#  - 0s - loss: 1.4486 - acc: 0.3778 - val_loss: 1.3133 - val_acc: 0.4165
# Epoch 9/10
#  - 0s - loss: 1.3872 - acc: 0.3970 - val_loss: 1.2730 - val_acc: 0.4604
# Epoch 10/10
#  - 0s - loss: 1.3454 - acc: 0.4179 - val_loss: 1.2538 - val_acc: 0.4615

# %%
epoch = 30
node = 64

model_total = keras.models.Sequential()
model_total.add(keras.layers.Flatten(input_shape=[12,]))

model_total.add(keras.layers.Dense(node))
model_total.add(keras.layers.BatchNormalization())
model_total.add(keras.layers.Activation('relu'))
model_total.add(keras.layers.Dropout(0.2))
model_total.add(keras.layers.Dense(node))
model_total.add(keras.layers.BatchNormalization())
model_total.add(keras.layers.Activation('relu'))
model_total.add(keras.layers.Dropout(0.2))
model_total.add(keras.layers.Dense(node))
model_total.add(keras.layers.BatchNormalization())
model_total.add(keras.layers.Activation('relu'))
model_total.add(keras.layers.Dropout(0.2))

model_total.add(keras.layers.Dense(10, activation="softmax"))

model_total.summary()

model_total.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history_total = model_total.fit(X_train_total, y_train_label,batch_size=32,epochs=epoch,verbose=2,validation_split=0.2)

visualization(history_total)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_90 (Flatten)         (None, 12)                0
# _________________________________________________________________
# dense_236 (Dense)            (None, 64)                832
# _________________________________________________________________
# batch_normalization_v1_67 (B (None, 64)                256
# _________________________________________________________________
# activation_67 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_237 (Dense)            (None, 64)                4160
# _________________________________________________________________
# batch_normalization_v1_68 (B (None, 64)                256
# _________________________________________________________________
# activation_68 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_238 (Dense)            (None, 64)                4160
# _________________________________________________________________
# batch_normalization_v1_69 (B (None, 64)                256
# _________________________________________________________________
# activation_69 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_239 (Dense)            (None, 10)                650
# =================================================================
# Total params: 10,570
# Trainable params: 10,186
# Non-trainable params: 384
# _________________________________________________________________
# Train on 3637 samples, validate on 910 samples
# Epoch 1/30
#  - 3s - loss: 1.8836 - acc: 0.3088 - val_loss: 1.5208 - val_acc: 0.4099
# Epoch 2/30
#  - 1s - loss: 1.3684 - acc: 0.4265 - val_loss: 1.4218 - val_acc: 0.3209
# Epoch 3/30
#  - 1s - loss: 1.1172 - acc: 0.5326 - val_loss: 1.3490 - val_acc: 0.2967
# Epoch 4/30
#  - 1s - loss: 0.7939 - acc: 0.7110 - val_loss: 0.7093 - val_acc: 0.7879
# Epoch 5/30
#  - 1s - loss: 0.5973 - acc: 0.8051 - val_loss: 1.0206 - val_acc: 0.3626
# Epoch 6/30
#  - 1s - loss: 0.4535 - acc: 0.8493 - val_loss: 0.4052 - val_acc: 0.8549
# Epoch 7/30
#  - 1s - loss: 0.3702 - acc: 0.8702 - val_loss: 0.2938 - val_acc: 0.9604
# Epoch 8/30
#  - 1s - loss: 0.3077 - acc: 0.8941 - val_loss: 0.1071 - val_acc: 0.9956
# Epoch 9/30
#  - 1s - loss: 0.2809 - acc: 0.9005 - val_loss: 0.1191 - val_acc: 0.9945
# Epoch 10/30
#  - 1s - loss: 0.2387 - acc: 0.9189 - val_loss: 0.0552 - val_acc: 0.9934
# Epoch 11/30
#  - 1s - loss: 0.2396 - acc: 0.9159 - val_loss: 0.0643 - val_acc: 0.9945
# Epoch 12/30
#  - 1s - loss: 0.2412 - acc: 0.9139 - val_loss: 0.0418 - val_acc: 0.9956
# Epoch 13/30
#  - 1s - loss: 0.2108 - acc: 0.9255 - val_loss: 0.0338 - val_acc: 0.9956
# Epoch 14/30
#  - 1s - loss: 0.1788 - acc: 0.9409 - val_loss: 0.0463 - val_acc: 0.9758
# Epoch 15/30
#  - 1s - loss: 0.1812 - acc: 0.9332 - val_loss: 0.0497 - val_acc: 0.9956
# Epoch 16/30
#  - 1s - loss: 0.1950 - acc: 0.9296 - val_loss: 0.0375 - val_acc: 0.9945
# Epoch 17/30
#  - 1s - loss: 0.1513 - acc: 0.9497 - val_loss: 0.0975 - val_acc: 0.9978
# Epoch 18/30
#  - 1s - loss: 0.1504 - acc: 0.9469 - val_loss: 0.0270 - val_acc: 0.9956
# Epoch 19/30
#  - 1s - loss: 0.1308 - acc: 0.9516 - val_loss: 0.0290 - val_acc: 1.0000
# Epoch 20/30
#  - 1s - loss: 0.1650 - acc: 0.9409 - val_loss: 0.0237 - val_acc: 0.9956
# Epoch 21/30
#  - 1s - loss: 0.1776 - acc: 0.9362 - val_loss: 0.0268 - val_acc: 0.9967
# Epoch 22/30
#  - 1s - loss: 0.1553 - acc: 0.9445 - val_loss: 0.0180 - val_acc: 0.9978
# Epoch 23/30
#  - 1s - loss: 0.1326 - acc: 0.9530 - val_loss: 0.0268 - val_acc: 0.9956
# Epoch 24/30
#  - 1s - loss: 0.1443 - acc: 0.9505 - val_loss: 0.0513 - val_acc: 0.9648
# Epoch 25/30
#  - 1s - loss: 0.1205 - acc: 0.9566 - val_loss: 0.0164 - val_acc: 0.9967
# Epoch 26/30
#  - 1s - loss: 0.1378 - acc: 0.9555 - val_loss: 0.0163 - val_acc: 0.9978
# Epoch 27/30
#  - 1s - loss: 0.1262 - acc: 0.9508 - val_loss: 0.0179 - val_acc: 1.0000
# Epoch 28/30
#  - 1s - loss: 0.1197 - acc: 0.9599 - val_loss: 0.0424 - val_acc: 0.9989
# Epoch 29/30
#  - 1s - loss: 0.1121 - acc: 0.9607 - val_loss: 0.0173 - val_acc: 1.0000
# Epoch 30/30
#  - 1s - loss: 0.1410 - acc: 0.9483 - val_loss: 0.0265 - val_acc: 0.9945

# %%
white_wine_temp = pd.read_csv("winequality-white.csv")
red_wine_temp = pd.read_csv("winequality-red.csv")
white_wine_temp['type'] = 0
red_wine_temp['type'] = 1
wine = pd.concat([white_wine_temp, red_wine_temp])

X_train_total, Y_train_total, X_test_total, Y_test_total = generate_data(wine, 0.7)
y_train_label = keras.utils.to_categorical(Y_train, 10)

model_type = keras.models.Sequential()
model_type.add(keras.layers.Flatten(input_shape=[13,]))

model_type.add(keras.layers.Dense(32, activation="relu"))
model_type.add(keras.layers.Dropout(0.2))

model_type.add(keras.layers.Dense(10, activation="softmax"))

model_type.summary()

model_type.compile(loss="categorical_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

history_total = model_type.fit(X_train_total, y_train_label,batch_size=32,epochs=10,verbose=2,validation_split=0.2)

visualization(history_total)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_96 (Flatten)         (None, 13)                0
# _________________________________________________________________
# dense_250 (Dense)            (None, 32)                448
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_251 (Dense)            (None, 10)                330
# =================================================================
# Total params: 778
# Trainable params: 778
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3637 samples, validate on 910 samples
# Epoch 1/10
#  - 3s - loss: 7.2808 - acc: 0.3041 - val_loss: 2.7955 - val_acc: 0.4066
# Epoch 2/10
#  - 0s - loss: 3.4574 - acc: 0.3445 - val_loss: 1.9500 - val_acc: 0.3967
# Epoch 3/10
#  - 0s - loss: 2.2688 - acc: 0.3374 - val_loss: 1.5351 - val_acc: 0.4440
# Epoch 4/10
#  - 0s - loss: 1.7136 - acc: 0.3539 - val_loss: 1.3061 - val_acc: 0.4956
# Epoch 5/10
#  - 0s - loss: 1.4728 - acc: 0.3932 - val_loss: 1.2788 - val_acc: 0.5132
# Epoch 6/10
#  - 0s - loss: 1.3800 - acc: 0.4141 - val_loss: 1.2445 - val_acc: 0.5253
# Epoch 7/10
#  - 0s - loss: 1.3501 - acc: 0.4226 - val_loss: 1.2056 - val_acc: 0.4681
# Epoch 8/10
#  - 0s - loss: 1.3085 - acc: 0.4344 - val_loss: 1.1968 - val_acc: 0.5022
# Epoch 9/10
#  - 0s - loss: 1.2786 - acc: 0.4512 - val_loss: 1.1645 - val_acc: 0.5220
# Epoch 10/10
#  - 0s - loss: 1.2520 - acc: 0.4531 - val_loss: 1.1530 - val_acc: 0.5451
